# %%
import pandas as pd

# %%
values = [1, 2, 3, 4, 5]
s = pd.Series(values, index=['a', 'b', 'c', 'd', 'e'])
print(s)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#Data frames
df = pd.DataFrame({
    "names" :['John', 'Jane', 'Sue', 'Fred', 'Lucy'],
    "ages" : [23, 29, 21, 18, 33],
    "department" :['HR', 'Engineering', 'Engineering', 'Marketing', 'HR']
})
df
#df = df.set_index('names')
# Out:
#   names  ages   department
# 0  John    23           HR
# 1  Jane    29  Engineering
# 2   Sue    21  Engineering
# 3  Fred    18    Marketing
# 4  Lucy    33           HR

# %%
df.to_csv('mydata.csv')

# %%
pd.read_csv('mydata.csv')
# Out:
#    Unnamed: 0 names  ages   department
# 0           0  John    23           HR
# 1           1  Jane    29  Engineering
# 2           2   Sue    21  Engineering
# 3           3  Fred    18    Marketing
# 4           4  Lucy    33           HR

# %%
from sklearn.datasets import fetch_california_housing
dfd = fetch_california_housing(as_frame=True).frame
dfd.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# ...

# %%
import matplotlib.pyplot as plt
dfd['HouseAge'].hist()
plt.title('Histogram of House Age')
plt.show()

# %%
dfd.hist(figsize=(12, 8))
plt.show()
plt.tight_layout()
dfd.plot()
# Out:
# <Axes: >

# %%
import yfinance as yf
stock_dfd = yf.download('AAPL', start='2020-01-01', end='2021-01-01')
stock_dfd.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %%
print(df)
# Out:
# 24.8

# %%
df.age
